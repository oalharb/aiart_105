# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import datetime
from IPython.display import Image
from PIL import Image
import time

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
haar_cascade_face = cv2.CascadeClassifier('cascadew.xml')

# %%
def detect_faces(cascade, test_image, scaleFactor =1.01):

    
    image_copy = test_image.copy()
    


    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)
   
    # Applying the haar classifier to detect faces
    faces_rect = cascade.detectMultiScale(gray_image,scaleFactor=scaleFactor, minNeighbors=10)
    i=1
    for (x, y, w, h) in faces_rect:
        return True
    return False

# %%
cap = cv2.VideoCapture(0)

z=0
height= 512
width=512
content_image_path = 'aiart.png'
content_image = Image.open(content_image_path)
content_image = content_image.resize((height, width))
printed= False
while True:
    ret, img = cap.read()
    faces = detect_faces(haar_cascade_face,img)
    if faces:
        if not printed:
            display(content_image)
            printed = True
    z+=1
    k = cv2.waitKey(1) & 0xff
    if k == 27:
        break
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x11CBF6748>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-c9f8167b39d3> in <module>
#      10 while True:
#      11     ret, img = cap.read()
# ---> 12     faces = detect_faces(haar_cascade_face,img)
#      13     if faces:
#      14         if not printed:
#
# <ipython-input-23-e50d4bdfa7df> in detect_faces(cascade, test_image, scaleFactor)
#       9
#      10     # Applying the haar classifier to detect faces
# ---> 11     faces_rect = cascade.detectMultiScale(gray_image,scaleFactor=scaleFactor, minNeighbors=10)
#      12     i=1
#      13     for (x, y, w, h) in faces_rect:
#
# KeyboardInterrupt:
